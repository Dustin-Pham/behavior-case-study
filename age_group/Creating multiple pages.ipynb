# %%
import pandas as pd

print('pandas imported!')
# Out:
# pandas imported!

# %%
import os
working_directory = os.getcwd()
print(working_directory)
# Out:
# C:\Users\dusti\behavior case study\python\age_group

# %%
path = working_directory + '/multiple_pages.csv'
df=pd.read_csv(path)

print(df)
# Out:
#                           Timestamp  age  Gender      Purchase_Frequency  \
# 0    2023/06/05 2:28:10 PM GMT+5:30   26    Male  Less than once a month
# 1    2023/06/04 9:10:51 PM GMT+5:30   23  Female       Few times a month
# 2    2023/06/04 9:18:12 PM GMT+5:30   24  Female   Multiple times a week
# 3    2023/06/06 4:25:49 PM GMT+5:30   27    Male            Once a month
# 4    2023/06/05 3:28:01 PM GMT+5:30   23    Male  Less than once a month
# ..                              ...  ...     ...                     ...
# 437  2023/06/12 3:42:05 PM GMT+5:30   41  Female             Once a week
# 438  2023/06/12 3:44:16 PM GMT+5:30   23  Female             Once a week
# 439  2023/06/12 3:45:27 PM GMT+5:30   23  Female   Multiple times a week
# 440  2023/06/12 3:47:01 PM GMT+5:30   45  Female   Multiple times a week
# 441  2023/06/12 3:48:11 PM GMT+5:30   25  Female       Few times a month
#
#                                    Purchase_Categories  \
# 0                                     Home and Kitchen
# 1    Beauty and Personal Care;Clothing and Fashion;...
# 2                           Groceries and Gourmet Food
# 3                                               others
# 4                                               others
# ..                                                 ...
# 437                           Beauty and Personal Care
# 438                           Beauty and Personal Care
# 439                           Beauty and Personal Care
# 440                           Beauty and Personal Care
# 441                           Beauty and Personal Care
#
#     Personalized_Recommendation_Frequency Browsing_Frequency  \
# 0                                      No             Rarely
# 1                                      No  Few times a month
# 2                                     Yes   Few times a week
# 3                               Sometimes  Few times a month
# 4                                      No             Rarely
# ..                                    ...                ...
# 437                             Sometimes   Few times a week
# 438                             Sometimes   Few times a week
# 439                                   Yes   Few times a week
# 440                             Sometimes   Few times a week
# 441                             Sometimes   Few times a week
#
#     Product_Search_Method Search_Result_Exploration  \
# 0                  Filter            Multiple pages
# 1                 Keyword            Multiple pages
# 2              categories            Multiple pages
# 3                 Keyword            Multiple pages
# 4              categories            Multiple pages
# ..                    ...                       ...
# 437            categories            Multiple pages
# 438               Keyword            Multiple pages
# 439               Keyword            Multiple pages
# 440            categories            Multiple pages
# 441            categories            Multiple pages
#
#      Customer_Reviews_Importance  ... Review_Left Review_Reliability  \
# 0                              1  ...         Yes         Moderately
# 1                              1  ...         Yes            Heavily
# 2                              1  ...         Yes         Moderately
# 3                              3  ...         Yes         Moderately
# 4                              1  ...          No            Heavily
# ..                           ...  ...         ...                ...
# 437                            3  ...         Yes         Moderately
# 438                            3  ...         Yes         Moderately
# 439                            3  ...         Yes       Occasionally
# 440                            3  ...         Yes         Moderately
# 441                            3  ...         Yes       Occasionally
#
#     Review_Helpfulness Personalized_Recommendation_Frequency_[0]  \
# 0                  Yes                                         1
# 1                  Yes                                         3
# 2                   No                                         2
# 3                  Yes                                         3
# 4                  Yes                                         2
# ..                 ...                                       ...
# 437          Sometimes                                         4
# 438          Sometimes                                         3
# 439          Sometimes                                         4
# 440          Sometimes                                         3
# 441          Sometimes                                         4
#
#     Recommendation_Helpfulness Rating_Accuracy Shopping_Satisfaction  \
# 0                          Yes               2                     1
# 1                    Sometimes               1                     1
# 2                           No               2                     3
# 3                    Sometimes               3                     1
# 4                           No               3                     2
# ..                         ...             ...                   ...
# 437                  Sometimes               3                     3
# 438                  Sometimes               3                     3
# 439                  Sometimes               3                     3
# 440                  Sometimes               3                     3
# 441                  Sometimes               4                     4
#
#                     Service_Appreciation                Improvement_Areas   id
# 0                 Wide product selection     Product quality and accuracy    1
# 1                     Competitive prices  Customer service responsiveness    2
# 2    User-friendly website/app interface     Product quality and accuracy    4
# 3                 Wide product selection     Product quality and accuracy    5
# 4    User-friendly website/app interface         Reducing packaging waste    6
# ..                                   ...                              ...  ...
# 437              Product recommendations     Product quality and accuracy  598
# 438                   Competitive prices  Customer service responsiveness  599
# 439                   Competitive prices  Customer service responsiveness  600
# 440              Product recommendations         Reducing packaging waste  601
# 441              Product recommendations         Reducing packaging waste  602
#
# [442 rows x 24 columns]

# %%
df.describe()
# Out:
#               age  Customer_Reviews_Importance  \
# count  442.000000                   442.000000
# mean    30.687783                     2.368778
# std     10.206142                     1.182726
# min     12.000000                     1.000000
# 25%     23.000000                     1.000000
# 50%     26.000000                     2.000000
# 75%     36.000000                     3.000000
# max     67.000000                     5.000000
#
#        Personalized_Recommendation_Frequency_[0]  Rating_Accuracy  \
# count                                 442.000000       442.000000
# mean                                    2.678733         2.622172
# std                                     1.060933         0.880505
# min                                     1.000000         1.000000
# 25%                                     2.000000         2.000000
# 50%                                     3.000000         3.000000
# 75%                                     3.000000         3.000000
# max                                     5.000000         5.000000
#
#        Shopping_Satisfaction          id
# count             442.000000  442.000000
# mean                2.398190  295.429864
# std                 0.998773  174.012148
# min                 1.000000    1.000000
# 25%                 2.000000  150.250000
# 50%                 2.000000  284.500000
# 75%                 3.000000  442.500000
# max                 5.000000  602.000000

# %%
# Split the column of age into three age groups
df["age_group"] = pd.cut(df["age"], bins=[10, 24, 54, 100], labels=["10-24", "25-54", "55-75"])

# Count the number of customers in each age group
age_group_counts = df.groupby("age_group").size()

# Add the age_group_counts Series to the existing table
df["age_group_counts"] = age_group_counts

print(df)
# Out:
#                           Timestamp  age  Gender      Purchase_Frequency  \
# 0    2023/06/05 2:28:10 PM GMT+5:30   26    Male  Less than once a month
# 1    2023/06/04 9:10:51 PM GMT+5:30   23  Female       Few times a month
# 2    2023/06/04 9:18:12 PM GMT+5:30   24  Female   Multiple times a week
# 3    2023/06/06 4:25:49 PM GMT+5:30   27    Male            Once a month
# 4    2023/06/05 3:28:01 PM GMT+5:30   23    Male  Less than once a month
# ..                              ...  ...     ...                     ...
# 437  2023/06/12 3:42:05 PM GMT+5:30   41  Female             Once a week
# 438  2023/06/12 3:44:16 PM GMT+5:30   23  Female             Once a week
# 439  2023/06/12 3:45:27 PM GMT+5:30   23  Female   Multiple times a week
# 440  2023/06/12 3:47:01 PM GMT+5:30   45  Female   Multiple times a week
# 441  2023/06/12 3:48:11 PM GMT+5:30   25  Female       Few times a month
#
#                                    Purchase_Categories  \
# 0                                     Home and Kitchen
# 1    Beauty and Personal Care;Clothing and Fashion;...
# 2                           Groceries and Gourmet Food
# 3                                               others
# 4                                               others
# ..                                                 ...
# 437                           Beauty and Personal Care
# 438                           Beauty and Personal Care
# 439                           Beauty and Personal Care
# 440                           Beauty and Personal Care
# 441                           Beauty and Personal Care
#
#     Personalized_Recommendation_Frequency Browsing_Frequency  \
# 0                                      No             Rarely
# 1                                      No  Few times a month
# 2                                     Yes   Few times a week
# 3                               Sometimes  Few times a month
# 4                                      No             Rarely
# ..                                    ...                ...
# 437                             Sometimes   Few times a week
# 438                             Sometimes   Few times a week
# 439                                   Yes   Few times a week
# 440                             Sometimes   Few times a week
# 441                             Sometimes   Few times a week
#
#     Product_Search_Method Search_Result_Exploration  \
# 0                  Filter            Multiple pages
# 1                 Keyword            Multiple pages
# 2              categories            Multiple pages
# 3                 Keyword            Multiple pages
# 4              categories            Multiple pages
# ..                    ...                       ...
# 437            categories            Multiple pages
# 438               Keyword            Multiple pages
# 439               Keyword            Multiple pages
# 440            categories            Multiple pages
# 441            categories            Multiple pages
#
#      Customer_Reviews_Importance  ... Review_Helpfulness  \
# 0                              1  ...                Yes
# 1                              1  ...                Yes
# 2                              1  ...                 No
# 3                              3  ...                Yes
# 4                              1  ...                Yes
# ..                           ...  ...                ...
# 437                            3  ...          Sometimes
# 438                            3  ...          Sometimes
# 439                            3  ...          Sometimes
# 440                            3  ...          Sometimes
# 441                            3  ...          Sometimes
#
#     Personalized_Recommendation_Frequency_[0] Recommendation_Helpfulness  \
# 0                                           1                        Yes
# 1                                           3                  Sometimes
# 2                                           2                         No
# 3                                           3                  Sometimes
# 4                                           2                         No
# ..                                        ...                        ...
# 437                                         4                  Sometimes
# 438                                         3                  Sometimes
# 439                                         4                  Sometimes
# 440                                         3                  Sometimes
# 441                                         4                  Sometimes
#
#     Rating_Accuracy Shopping_Satisfaction  \
# 0                 2                     1
# 1                 1                     1
# 2                 2                     3
# 3                 3                     1
# 4                 3                     2
# ..              ...                   ...
# 437               3                     3
# 438               3                     3
# 439               3                     3
# 440               3                     3
# 441               4                     4
#
#                     Service_Appreciation                Improvement_Areas  \
# 0                 Wide product selection     Product quality and accuracy
# 1                     Competitive prices  Customer service responsiveness
# 2    User-friendly website/app interface     Product quality and accuracy
# 3                 Wide product selection     Product quality and accuracy
# 4    User-friendly website/app interface         Reducing packaging waste
# ..                                   ...                              ...
# 437              Product recommendations     Product quality and accuracy
# 438                   Competitive prices  Customer service responsiveness
# 439                   Competitive prices  Customer service responsiveness
# 440              Product recommendations         Reducing packaging waste
# 441              Product recommendations         Reducing packaging waste
#
#       id age_group  age_group_counts
# 0      1     25-54               NaN
# 1      2     10-24               NaN
# 2      4     10-24               NaN
# 3      5     25-54               NaN
# 4      6     10-24               NaN
# ..   ...       ...               ...
# 437  598     25-54               NaN
# 438  599     10-24               NaN
# 439  600     10-24               NaN
# 440  601     25-54               NaN
# 441  602     25-54               NaN
#
# [442 rows x 26 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv("updated_multiple_pages.csv")

# %%
df.isnull()
# Out:
#      Timestamp    age  Gender  Purchase_Frequency  Purchase_Categories  \
# 0        False  False   False               False                False
# 1        False  False   False               False                False
# 2        False  False   False               False                False
# 3        False  False   False               False                False
# 4        False  False   False               False                False
# ..         ...    ...     ...                 ...                  ...
# 437      False  False   False               False                False
# 438      False  False   False               False                False
# 439      False  False   False               False                False
# 440      False  False   False               False                False
# 441      False  False   False               False                False
#
#      Personalized_Recommendation_Frequency  Browsing_Frequency  \
# 0                                    False               False
# 1                                    False               False
# 2                                    False               False
# 3                                    False               False
# 4                                    False               False
# ..                                     ...                 ...
# 437                                  False               False
# 438                                  False               False
# 439                                  False               False
# 440                                  False               False
# 441                                  False               False
#
#      Product_Search_Method  Search_Result_Exploration  \
# 0                    False                      False
# 1                    False                      False
# 2                    False                      False
# 3                    False                      False
# 4                    False                      False
# ..                     ...                        ...
# 437                  False                      False
# 438                  False                      False
# 439                  False                      False
# 440                  False                      False
# 441                  False                      False
#
#      Customer_Reviews_Importance  ...  Review_Helpfulness  \
# 0                          False  ...               False
# 1                          False  ...               False
# 2                          False  ...               False
# 3                          False  ...               False
# 4                          False  ...               False
# ..                           ...  ...                 ...
# 437                        False  ...               False
# 438                        False  ...               False
# 439                        False  ...               False
# 440                        False  ...               False
# 441                        False  ...               False
#
#      Personalized_Recommendation_Frequency_[0]  Recommendation_Helpfulness  \
# 0                                        False                       False
# 1                                        False                       False
# 2                                        False                       False
# 3                                        False                       False
# 4                                        False                       False
# ..                                         ...                         ...
# 437                                      False                       False
# 438                                      False                       False
# 439                                      False                       False
# 440                                      False                       False
# 441                                      False                       False
#
#      Rating_Accuracy  Shopping_Satisfaction  Service_Appreciation  \
# 0              False                  False                 False
# 1              False                  False                 False
# 2              False                  False                 False
# 3              False                  False                 False
# 4              False                  False                 False
# ..               ...                    ...                   ...
# 437            False                  False                 False
# 438            False                  False                 False
# 439            False                  False                 False
# 440            False                  False                 False
# 441            False                  False                 False
#
#      Improvement_Areas     id  age_group  age_group_counts
# 0                False  False      False              True
# 1                False  False      False              True
# 2                False  False      False              True
# 3                False  False      False              True
# 4                False  False      False              True
# ..                 ...    ...        ...               ...
# 437              False  False      False              True
# 438              False  False      False              True
# 439              False  False      False              True
# 440              False  False      False              True
# 441              False  False      False              True
#
# [442 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Timestamp                                      0
# age                                            0
# Gender                                         0
# Purchase_Frequency                             0
# Purchase_Categories                            0
# Personalized_Recommendation_Frequency          0
# Browsing_Frequency                             0
# Product_Search_Method                          2
# Search_Result_Exploration                      0
# Customer_Reviews_Importance                    0
# Add_to_Cart_Browsing                           0
# Cart_Completion_Frequency                      0
# Cart_Abandonment_Factors                       0
# Saveforlater_Frequency                         0
# Review_Left                                    0
# Review_Reliability                             0
# Review_Helpfulness                             0
# Personalized_Recommendation_Frequency_[0]      0
# Recommendation_Helpfulness                     0
# Rating_Accuracy                                0
# Shopping_Satisfaction                          0
# Service_Appreciation                           0
# Improvement_Areas                              0
# id                                             0
# age_group                                      0
# age_group_counts                             442
# dtype: int64

# %%
df=df.drop(columns=['age_group_counts'])

# %%
df.isnull().sum()
# Out:
# Timestamp                                    0
# age                                          0
# Gender                                       0
# Purchase_Frequency                           0
# Purchase_Categories                          0
# Personalized_Recommendation_Frequency        0
# Browsing_Frequency                           0
# Product_Search_Method                        2
# Search_Result_Exploration                    0
# Customer_Reviews_Importance                  0
# Add_to_Cart_Browsing                         0
# Cart_Completion_Frequency                    0
# Cart_Abandonment_Factors                     0
# Saveforlater_Frequency                       0
# Review_Left                                  0
# Review_Reliability                           0
# Review_Helpfulness                           0
# Personalized_Recommendation_Frequency_[0]    0
# Recommendation_Helpfulness                   0
# Rating_Accuracy                              0
# Shopping_Satisfaction                        0
# Service_Appreciation                         0
# Improvement_Areas                            0
# id                                           0
# age_group                                    0
# dtype: int64

# %%
dfresult = df.dropna()

# %%
dfresult.isnull().sum()
# Out:
# Timestamp                                    0
# age                                          0
# Gender                                       0
# Purchase_Frequency                           0
# Purchase_Categories                          0
# Personalized_Recommendation_Frequency        0
# Browsing_Frequency                           0
# Product_Search_Method                        0
# Search_Result_Exploration                    0
# Customer_Reviews_Importance                  0
# Add_to_Cart_Browsing                         0
# Cart_Completion_Frequency                    0
# Cart_Abandonment_Factors                     0
# Saveforlater_Frequency                       0
# Review_Left                                  0
# Review_Reliability                           0
# Review_Helpfulness                           0
# Personalized_Recommendation_Frequency_[0]    0
# Recommendation_Helpfulness                   0
# Rating_Accuracy                              0
# Shopping_Satisfaction                        0
# Service_Appreciation                         0
# Improvement_Areas                            0
# id                                           0
# age_group                                    0
# dtype: int64

# %%
# Save the DataFrame to a CSV file
dfresult.to_csv("updated_multiple_pages.csv")
